# %% [markdown]
# <a href="https://colab.research.google.com/github/durgakiran/tensorflow-examples/blob/master/Building_a_Recurrent_Neural_Network_in_TensorFlow_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Stage 1: Install dependencies and setting up GPU environment

# %%
# !pip install numpy==1.16.1
# !pip install tensorflow-gpu==2.0.0

# %% [markdown]
# ## Stage 2: Importing project dependencies

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import imdb

# %%
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ## Stage 3: Dataset preprocessing

# %% [markdown]
# ### Setting up dataset parameters

# %%
#total number of top words to be considered
number_of_words = 20000
#max length of the sequence
max_len = 100

# %% [markdown]
# ### Loading the IMDB dataset

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=number_of_words)

# %% [markdown]
# ### Padding all sequences to be the same length

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_len)#all our sequencies will be of 100 length

# %%
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_len)#all our sequencies will be of 100 length

# %% [markdown]
# ### Setting up Embedding Layer parameters

# %%
vocab_size = number_of_words
vocab_size
# Out:
# 20000

# %%
embed_size = 128 #output dimenstion of Embedding layer

# %%
X_train.shape
# Out:
# (25000, 100)

# %% [markdown]
# ## Step 4: Building a Recurrent Neural Network

# %% [markdown]
# ### Defining the model

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ### Adding the Embeding Layer

# %%
#Embedding layer is used to prepare a word vector matrix
#here shape is input vector shape of each sequence
model.add(tf.keras.layers.Embedding(vocab_size, embed_size, input_shape=(X_train.shape[1],)))

# %% [markdown]
# ### Adding the LSTM Layer
#
# - units: 128
# - activation: tanh

# %%
#units=no of LSTM units
model.add(tf.keras.layers.LSTM(units=128, activation='tanh'))

# %% [markdown]
# ### Adding the Dense output layer
#
# - units: 1
# - activation: sigmoid

# %%
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Compiling the model

# %%
#rmsprop is the most used optimizer for RNN networks
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 100, 128)          2560000
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# ...
# Total params: 2,691,713
# Trainable params: 2,691,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train, y_train, epochs=3, batch_size=128)
# Out:
# Train on 25000 samples
# Epoch 1/3
# 25000/25000 [==============================] - 15s 594us/sample - loss: 0.4564 - accuracy: 0.7893
# Epoch 2/3
# 25000/25000 [==============================] - 7s 276us/sample - loss: 0.2875 - accuracy: 0.8860
# Epoch 3/3
# 25000/25000 [==============================] - 7s 274us/sample - loss: 0.2325 - accuracy: 0.9095

# %% [markdown]
# ### Evaluating the model

# %%
test_loss, test_acurracy = model.evaluate(X_test, y_test)
# Out:
# 25000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print("Test accuracy: {}".format(test_acurracy))
# Out:
# Test accuracy: 0.8533999919891357
